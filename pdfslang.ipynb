# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 49.2 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-5_khrmtg
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-5_khrmtg
#   Resolved https://github.com/huggingface/transformers to commit b338a6c3b8eda29610d4d472cad8cd87cbfdaaed
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.39.0.dev0-py3-none-any.whl size=8660843 sha256=a668bdc80ab100d3988783ac7704403b108d79541f0eb3706830cc7e8b100485
#   Stored in directory: /tmp/pip-ephem-wheel-cache-of451jk3/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
# ...

# %%
# !virtualenv /content/drive/MyDrive/colab_env
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 54666ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/colab_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install langchain

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install sentence_transformers
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install faiss-cpu
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install huggingface-hub

# %%
! pip show accelerate
# Out:
# WARNING: Package(s) not found: accelerate

# %%
! pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install accelerate
# Out:
# ...
#   Using cached accelerate-0.27.2-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached accelerate-0.27.2-py3-none-any.whl (279 kB)
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip uninstall accelerate
# Out:
# Found existing installation: accelerate 0.27.2
# Uninstalling accelerate-0.27.2:
#   Would remove:
#     /content/drive/MyDrive/colab_env/bin/accelerate
#     /content/drive/MyDrive/colab_env/bin/accelerate-config
#     /content/drive/MyDrive/colab_env/bin/accelerate-estimate-memory
#     /content/drive/MyDrive/colab_env/bin/accelerate-launch
#     /content/drive/MyDrive/colab_env/lib/python3.10/site-packages/accelerate-0.27.2.dist-info/*
#     /content/drive/MyDrive/colab_env/lib/python3.10/site-packages/accelerate/*
# Proceed (Y/n)? Y
#   Successfully uninstalled accelerate-0.27.2

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install optimum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 36.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 27.3 MB/s eta 0:00:00
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install transformers
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
! pip show accelerate
# Out:
# Name: accelerate
# Version: 0.27.2
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: sylvain@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by: auto_gptq, peft

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install auto-gptq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 16.3 MB/s eta 0:00:00
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip show accelerate
# Out:
# Name: accelerate
# Version: 0.27.2
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: sylvain@huggingface.co
# License: Apache
# Location: /content/drive/MyDrive/colab_env/lib/python3.10/site-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by: auto_gptq, peft

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install huggingface_hub

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.append("/content/drive/MyDrive/colab_env/lib/python3.10/site-packages")

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from langchain.vectorstores import FAISS

# %%
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings

# %%
loader = PyPDFDirectoryLoader("/content/drive/MyDrive/Colab Notebooks/Chatpdfslangchain")

# %%
data=loader.load()

# %%
data
# Out:
# [Document(page_content='Conversion of Pseudo-code to Python Source Code\nAllwyn Bat Thomas1*, Ananya Reetha Noble2*, Anna Wilson3*, Leya Elizabeth Sunny4*\n*Department of Computer Science and Engineering\nMar Athanasius College of Engineering, Kothamangalam, Kerala\n1allwynbatthomas@gmail.com,2ananyarita@gmail.com,3annawilsonleo@gmail.com,4leyabejoy81@gmail.com\nAbstract —Pseudo-code is an informal means of representing\nalgorithms using plain language, serving as a vital tool for ef-\nfective communication among developers and researchers. How-\never, converting human-readable pseudo-code into executable\nsource code presents numerous challenges. Manual conversion,\nin particular, is error-prone and time-consuming. However, an\nautomated pseudo-code to the Python conversion system utilizing\nthe fine-tuned Mistral 7B model can streamline this process.\nThe fine-tuning procedure optimizes the model’s parameters to\nachieve peak performance on this specific conversion task. The\nMistr
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=20)

# %%
text_chunks=text_splitter.split_documents(data)

# %%
len(text_chunks)
# Out:
# 5

# %%
text_chunks
# Out:
# [Document(page_content='Conversion of Pseudo-code to Python Source Code\nAllwyn Bat Thomas1*, Ananya Reetha Noble2*, Anna Wilson3*, Leya Elizabeth Sunny4*\n*Department of Computer Science and Engineering\nMar Athanasius College of Engineering, Kothamangalam, Kerala\n1allwynbatthomas@gmail.com,2ananyarita@gmail.com,3annawilsonleo@gmail.com,4leyabejoy81@gmail.com\nAbstract —Pseudo-code is an informal means of representing\nalgorithms using plain language, serving as a vital tool for ef-\nfective communication among developers and researchers. How-\never, converting human-readable pseudo-code into executable\nsource code presents numerous challenges. Manual conversion,\nin particular, is error-prone and time-consuming. However, an\nautomated pseudo-code to the Python conversion system utilizing\nthe fine-tuned Mistral 7B model can streamline this process.\nThe fine-tuning procedure optimizes the model’s parameters to\nachieve peak performance on this specific conversion task. The\nMistr
# ...

# %%
embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
vector_store = FAISS.from_documents(text_chunks, embedding=embeddings)

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from langchain.llms import HuggingFaceHub

# %%
from langchain.llms import HuggingFaceEndpoint

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.1"
llm = HuggingFaceEndpoint(huggingfacehub_api_token='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',
                     repo_id=repo_id, temperature=0.1)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vector_store.as_retriever(search_kwargs={"k": 3}))

# %%
query = "What is sliding window attention?"
response = qa.invoke(query)

# %%
response['result']
# Out:
# ' Sliding window attention is a type of attention mechanism used in transformer models. It is a variant of self-attention, where each token attends to a fixed-sized window of previous tokens. The key, query, and value matrices are all the same in sliding window attention, and a causal mask is applied to ensure that each token depends only on the previous tokens within the window size.'
